# %% [markdown]
# # `ipyprofiler` demos
#
# - Flamegraph
#   - [Simple JSON `Flamegraph`](01_flamegraph.ipynb#Simple-Flamegraph)
# - Python
#   - [`Pyinstrument`](02_python.ipynb#Pyinstrument)
#     - [Basic Example](02_python.ipynb#Basic-Example)
#     - [Asynchronous Code](02_python.ipynb#Asynchronous-Code)
#     - [Multiple Cells](02_python.ipynb#Multiple-Cells)
